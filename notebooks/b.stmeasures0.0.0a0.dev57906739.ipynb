# %%
import stmeasures

# %%
g = stmeasures.read_file("../assets/ECATEPEC.json")

# %%
len(g[0]), len(g[1]), len(g[2])
# Out:
# (160, 636, 87)

# %%
stmeasures.distance(g[0], g[1][0:160])
# Out:
# 0.025032043823892926

# %%
stmeasures.distance_temporal(g[1], g[3])
# Out:
# /home/edev/devel/similarity-measures/venv/lib/python3.12/site-packages/stmeasures/calculate/dtw.py:56: UserWarning: Args not validating
#   warnings.warn('Args not validating')
# 22774.633635467366
