# %% [markdown]
# # Pruebas _in vitro_
#
# Para realizar estas pruebas, se escogieron trayectorias similares del GeoJSON generado en Ecatepec, así como algunas trayectorias similares hechas en [geojson.io](https://geojson.io/).
#
# Primeramente importamos algunas librerías que nos servirán para estas pruebas, incluyendo la nuestra.

# %%
import json
import stmeasures
import utils

# %% [markdown]
# Una vez importadas estas librerías, se procede a leer algunos archivos GeoJSON.

# %%
g_ecatepec = stmeasures.read_file('../assets/ECATEPEC.json')
g_similar = utils.read_file('../assets/map.geojson')
g_similar_u = utils.read_file('../assets/u.geojson')

# %% [markdown]
# ## Trayectorias similares
# Primeramente se calculan trayectorias que se vean similares, tanto en forma como su proximidad sea cercana.
#
# ### Usando trayectorias en ECATEPEC.json
# Se extrajeron algunas trayectorias del GeoJSON de Ecatepec.
#
# #### Primeras trayectorias similares

# %%
ecatepec_similar1 = [31, 48]

utils.calculate_all(*utils.get_trajectories(g_ecatepec, ecatepec_similar1))
# Out:
# The two sequences must have the same length.
# Algoritmo euclideano no pudo ser calculado
#
# Distancia Hausdorff: 0.0076363365562283955
# Distancia Frechet: 0.07134625913107955
# Distancia DTW: 689.6217498817439
# Distancia LCSS: 0.24691358024691357
# Distancia ERP: 21706.848575000036
# Distancia ERS: 180.0
# /home/edev/devel/similarity-measures/venv/lib/python3.12/site-packages/stmeasures/calculate/hausdorff.py:53: UserWarning: Args not validating
#   warnings.warn('Args not validating')
# /home/edev/devel/similarity-measures/venv/lib/python3.12/site-packages/stmeasures/calculate/frechet.py:53: UserWarning: Args not validating
#   warnings.warn('Args not validating')
# /home/edev/devel/similarity-measures/venv/lib/python3.12/site-packages/stmeasures/calculate/dtw.py:56: UserWarning: Args not validating
#   warnings.warn('Args not validating')
# ...

# %% [markdown]
# ![image](https://github.com/user-attachments/assets/8db983e2-6afa-45f0-901d-3d9b570e3355)

# %%
utils.calculate_all(*utils.get_trajectories(g_ecatepec, ecatepec_similar1), convert=True)
# Out:
# Distancia Euclideana: 0.524478350463553
# Distancia Hausdorff: 0.00782143209393914
# Distancia Frechet: 0.07134625913107955
# Distancia DTW: 151.39557846973094
# Distancia LCSS: 1.0
# Distancia ERP: 5.309794999999671
# Distancia ERS: 60.0
# /home/edev/devel/similarity-measures/venv/lib/python3.12/site-packages/stmeasures/calculate/hausdorff.py:53: UserWarning: Args not validating
#   warnings.warn('Args not validating')
# /home/edev/devel/similarity-measures/venv/lib/python3.12/site-packages/stmeasures/calculate/frechet.py:53: UserWarning: Args not validating
#   warnings.warn('Args not validating')
# /home/edev/devel/similarity-measures/venv/lib/python3.12/site-packages/stmeasures/calculate/dtw.py:56: UserWarning: Args not validating
#   warnings.warn('Args not validating')
# /home/edev/devel/similarity-measures/venv/lib/python3.12/site-packages/shapely/measurement.py:218: RuntimeWarning: invalid value encountered in hausdorff_distance
# ...

# %% [markdown]
# ![image](https://github.com/user-attachments/assets/a09d7f53-4b05-4f60-9262-42e58e01e8e4)

# %% [markdown]
# #### Segundas trayectorias similares

# %%
ecatepec_similar2 = [18, 22]
utils.calculate_all(*utils.get_trajectories(g_ecatepec, ecatepec_similar2))
# Out:
# The two sequences must have the same length.
# Algoritmo euclideano no pudo ser calculado
#
# Distancia Hausdorff: 0.0498307568174417
# Distancia Frechet: 0.06621928013049236
# Distancia DTW: 910.3009667626588
# Distancia LCSS: 0.45936395759717313
# Distancia ERP: 18155.21483999998
# Distancia ERS: 283.0
# /home/edev/devel/similarity-measures/venv/lib/python3.12/site-packages/stmeasures/calculate/hausdorff.py:53: UserWarning: Args not validating
#   warnings.warn('Args not validating')
# /home/edev/devel/similarity-measures/venv/lib/python3.12/site-packages/stmeasures/calculate/frechet.py:53: UserWarning: Args not validating
#   warnings.warn('Args not validating')
# /home/edev/devel/similarity-measures/venv/lib/python3.12/site-packages/stmeasures/calculate/dtw.py:56: UserWarning: Args not validating
#   warnings.warn('Args not validating')
# ...

# %% [markdown]
# ![image](https://github.com/user-attachments/assets/33d162c2-a201-4551-b2f4-15389f9cfead)

# %%
utils.calculate_all(*utils.get_trajectories(g_ecatepec, ecatepec_similar2), convert=True)
# Out:
# Distancia Euclideana: 0.4315818930400216
# Distancia Hausdorff: 0.049870203298154774
# Distancia Frechet: 0.06865773107232939
# Distancia DTW: 302.3825380753287
# Distancia LCSS: 1.0
# Distancia ERP: 5.671860000000194
# Distancia ERS: 130.0
# /home/edev/devel/similarity-measures/venv/lib/python3.12/site-packages/stmeasures/calculate/hausdorff.py:53: UserWarning: Args not validating
#   warnings.warn('Args not validating')
# /home/edev/devel/similarity-measures/venv/lib/python3.12/site-packages/stmeasures/calculate/frechet.py:53: UserWarning: Args not validating
#   warnings.warn('Args not validating')
# /home/edev/devel/similarity-measures/venv/lib/python3.12/site-packages/stmeasures/calculate/dtw.py:56: UserWarning: Args not validating
#   warnings.warn('Args not validating')
# /home/edev/devel/similarity-measures/venv/lib/python3.12/site-packages/shapely/measurement.py:218: RuntimeWarning: invalid value encountered in hausdorff_distance
# ...

# %% [markdown]
# ![image](https://github.com/user-attachments/assets/57ca979c-4113-4460-8d1a-dd0f6c7991ce)

# %% [markdown]
# ### Trayectorias hechas con geojsonio
# Ahora se realizaron algunas trayectorias similares manualmente.
#
# #### Terceras trayectorias similares

# %%
t1 = [(trajectory[1], trajectory[0]) for trajectory in g_similar['features'][0]['geometry']['coordinates']]
t2 = [(trajectory[1], trajectory[0]) for trajectory in g_similar['features'][1]['geometry']['coordinates']]

utils.calculate_all(t1, t2)
# Out:
# The two sequences must have the same length.
# Algoritmo euclideano no pudo ser calculado
#
# Distancia Hausdorff: 0.013225798847342454
# Distancia Frechet: 0.013225798847342454
# Distancia DTW: 1.6065549486941109
# Distancia LCSS: 0.5555555555555556
# Distancia ERP: 948.7763772085405
# Distancia ERS: 18.0
# /home/edev/devel/similarity-measures/venv/lib/python3.12/site-packages/stmeasures/calculate/hausdorff.py:53: UserWarning: Args not validating
#   warnings.warn('Args not validating')
# /home/edev/devel/similarity-measures/venv/lib/python3.12/site-packages/stmeasures/calculate/frechet.py:53: UserWarning: Args not validating
#   warnings.warn('Args not validating')
# /home/edev/devel/similarity-measures/venv/lib/python3.12/site-packages/stmeasures/calculate/dtw.py:56: UserWarning: Args not validating
#   warnings.warn('Args not validating')

# %% [markdown]
# ![image.png](attachment:fdb1cd17-debe-4382-92ad-f4ac34253fc4.png)

# %%
utils.calculate_all(t1, t2, convert=True)
# Out:
# Distancia Euclideana: 0.06563859392993317
# Distancia Hausdorff: 0.027642786458732714
# Distancia Frechet: 0.027642786458732714
# Distancia DTW: 0.9778077778354284
# Distancia LCSS: 1.0
# Distancia ERP: 0.2665744159481136
# Distancia ERS: 10.0
# /home/edev/devel/similarity-measures/venv/lib/python3.12/site-packages/stmeasures/calculate/hausdorff.py:53: UserWarning: Args not validating
#   warnings.warn('Args not validating')
# /home/edev/devel/similarity-measures/venv/lib/python3.12/site-packages/stmeasures/calculate/frechet.py:53: UserWarning: Args not validating
#   warnings.warn('Args not validating')
# /home/edev/devel/similarity-measures/venv/lib/python3.12/site-packages/stmeasures/calculate/dtw.py:56: UserWarning: Args not validating
#   warnings.warn('Args not validating')

# %% [markdown]
# ![image.png](attachment:65d47376-bb91-4660-8377-b4a5f6add133.png)

# %% [markdown]
# #### Cuartas trayectorias similares

# %%
t3 = [(trajectory[1], trajectory[0]) for trajectory in g_similar_u['features'][0]['geometry']['coordinates']]
t4 = [(trajectory[1], trajectory[0]) for trajectory in g_similar_u['features'][1]['geometry']['coordinates']]

utils.calculate_all(t3, t4)
# Out:
# Distancia Euclideana: 0.14027033982926937
# Distancia Hausdorff: 0.049728190901368645
# Distancia Frechet: 0.049728190901368645
# Distancia DTW: 2.1205209948530994
# Distancia LCSS: 1.0
# Distancia ERP: 0.567292582846818
# Distancia ERS: 9.0
# /home/edev/devel/similarity-measures/venv/lib/python3.12/site-packages/stmeasures/calculate/hausdorff.py:53: UserWarning: Args not validating
#   warnings.warn('Args not validating')
# /home/edev/devel/similarity-measures/venv/lib/python3.12/site-packages/stmeasures/calculate/frechet.py:53: UserWarning: Args not validating
#   warnings.warn('Args not validating')
# /home/edev/devel/similarity-measures/venv/lib/python3.12/site-packages/stmeasures/calculate/dtw.py:56: UserWarning: Args not validating
#   warnings.warn('Args not validating')

# %% [markdown]
# ![image.png](attachment:17fd36d8-8dea-49e6-bd76-5cc9a779dee2.png)

# %% [markdown]
# ## Trayectorias varias
# Ahora se analizan algunas otras trayectorias varias del GeoJSON del Ecatepec.
#
# ### Quintas trayectorias varias

# %%
ecatepec_other1 = [100, 203]

utils.calculate_all(*utils.get_trajectories(g_ecatepec, ecatepec_other1))
# Out:
# The two sequences must have the same length.
# Algoritmo euclideano no pudo ser calculado
#
# Distancia Hausdorff: 0.10990432960534563
# Distancia Frechet: 0.10990432960534563
# Distancia DTW: 11119.256931442522
# Distancia LCSS: 0.4429657794676806
# Distancia ERP: 34770.53177599992
# Distancia ERS: 526.0
# /home/edev/devel/similarity-measures/venv/lib/python3.12/site-packages/stmeasures/calculate/hausdorff.py:53: UserWarning: Args not validating
#   warnings.warn('Args not validating')
# /home/edev/devel/similarity-measures/venv/lib/python3.12/site-packages/stmeasures/calculate/frechet.py:53: UserWarning: Args not validating
#   warnings.warn('Args not validating')
# /home/edev/devel/similarity-measures/venv/lib/python3.12/site-packages/stmeasures/calculate/dtw.py:56: UserWarning: Args not validating
#   warnings.warn('Args not validating')
# ...

# %% [markdown]
# ![image.png](attachment:c62852f8-0802-45e9-8568-da87e0f9d62e.png)

# %%
utils.calculate_all(*utils.get_trajectories(g_ecatepec, ecatepec_other1), convert=True)
# Out:
# Distancia Euclideana: 0.5547949539721871
# Distancia Hausdorff: 0.054582598921273456
# Distancia Frechet: 0.06090889327513002
# Distancia DTW: 958.8138661358166
# Distancia LCSS: 1.0
# Distancia ERP: 10.038455000000024
# Distancia ERS: 233.0
# /home/edev/devel/similarity-measures/venv/lib/python3.12/site-packages/stmeasures/calculate/hausdorff.py:53: UserWarning: Args not validating
#   warnings.warn('Args not validating')
# /home/edev/devel/similarity-measures/venv/lib/python3.12/site-packages/stmeasures/calculate/frechet.py:53: UserWarning: Args not validating
#   warnings.warn('Args not validating')
# /home/edev/devel/similarity-measures/venv/lib/python3.12/site-packages/stmeasures/calculate/dtw.py:56: UserWarning: Args not validating
#   warnings.warn('Args not validating')
# /home/edev/devel/similarity-measures/venv/lib/python3.12/site-packages/shapely/measurement.py:218: RuntimeWarning: invalid value encountered in hausdorff_distance
# ...

# %% [markdown]
# ![image.png](attachment:95740ce4-f153-4a6e-95cf-0aae810b7add.png)

# %% [markdown]
# ### Sextas trayectorias varias

# %%
ecatepec_other2 = [444, 555]

utils.calculate_all(*utils.get_trajectories(g_ecatepec, ecatepec_other2))
# Out:
# The two sequences must have the same length.
# Algoritmo euclideano no pudo ser calculado
#
# Distancia Hausdorff: 0.06605772944932944
# Distancia Frechet: 0.06605772944932944
# Distancia DTW: 196.68379306080917
# Distancia LCSS: 0.8
# Distancia ERP: 2138.8717579999993
# Distancia ERS: 90.0
# /home/edev/devel/similarity-measures/venv/lib/python3.12/site-packages/stmeasures/calculate/hausdorff.py:53: UserWarning: Args not validating
#   warnings.warn('Args not validating')
# /home/edev/devel/similarity-measures/venv/lib/python3.12/site-packages/stmeasures/calculate/frechet.py:53: UserWarning: Args not validating
#   warnings.warn('Args not validating')
# /home/edev/devel/similarity-measures/venv/lib/python3.12/site-packages/stmeasures/calculate/dtw.py:56: UserWarning: Args not validating
#   warnings.warn('Args not validating')
# ...

# %% [markdown]
# ![image.png](attachment:705c0e1d-a3c2-4e62-b5f7-f98068b59e15.png)

# %%
utils.calculate_all(*utils.get_trajectories(g_ecatepec, ecatepec_other2), convert=True)
# Out:
# Distancia Euclideana: 0.5209106320396937
# Distancia Hausdorff: 0.06605772944932944
# Distancia Frechet: 0.06605772944932944
# Distancia DTW: 157.15877987264383
# Distancia LCSS: 1.0
# Distancia ERP: 5.376161999999823
# Distancia ERS: 72.0
# /home/edev/devel/similarity-measures/venv/lib/python3.12/site-packages/stmeasures/calculate/hausdorff.py:53: UserWarning: Args not validating
#   warnings.warn('Args not validating')
# /home/edev/devel/similarity-measures/venv/lib/python3.12/site-packages/stmeasures/calculate/frechet.py:53: UserWarning: Args not validating
#   warnings.warn('Args not validating')
# /home/edev/devel/similarity-measures/venv/lib/python3.12/site-packages/stmeasures/calculate/dtw.py:56: UserWarning: Args not validating
#   warnings.warn('Args not validating')
# /home/edev/devel/similarity-measures/venv/lib/python3.12/site-packages/shapely/measurement.py:218: RuntimeWarning: invalid value encountered in hausdorff_distance
# ...

# %% [markdown]
# ![image.png](attachment:82ffb9d0-3eb7-444c-a5fe-1c4728c487ce.png)

# %% [markdown]
# ## Resultados compilados
#
# ### Trayectorias
#
# | 1.1 | 1.2 | 2.1 | 2.2 | 3.1 | 3.2 |
# |-----|-----|-----|-----|-----|-----|
# | ![image](https://camo.githubusercontent.com/ddac64237bb23d8806f1d7c0ca18b70ea2cf1735ef33f38adf07a0226e357b6a/68747470733a2f2f6769746875622e636f6d2f757365722d6174746163686d656e74732f6173736574732f38646239383365322d366166612d343566302d393031642d336439623537306533333535) | ![image](https://camo.githubusercontent.com/1798055ffd7a7f97bef4783fa9ec04323a3509dfed6c2d22d2b4acb11033feb4/68747470733a2f2f6769746875622e636f6d2f757365722d6174746163686d656e74732f6173736574732f61303964376635332d346230352d346636302d393236322d343265353865303165386534) | ![image](https://camo.githubusercontent.com/0a06dbd8e45a2938ba5c9961e30c9d7c9b2a7bcd50940b2974a3043e8942a956/68747470733a2f2f6769746875622e636f6d2f757365722d6174746163686d656e74732f6173736574732f33336431363263322d613230312d343535312d623266342d313533383966396366656164) | ![image](https://camo.githubusercontent.com/3193d37038b165263a0c5e4acea863df8b3bd54e01854fe33aebeba20c1a6e05/68747470733a2f2f6769746875622e636f6d2f757365722d6174746163686d656e74732f6173736574732f35376361393739632d343131332d343436302d386431612d646430663663373939316365) | ![image.png](attachment:88d4ae5d-9380-4487-9977-5c35ff2774f8.png) | ![image.png](attachment:0fa74509-c843-4da6-a3c0-7d1716161566.png) |
#
# | 4.1 | 5.1 | 5.2 | 6.1 | 6.2 |
# |-----|-----|-----|-----|-----|
# | ![image.png](attachment:e048ffba-4a27-4079-9651-8e3aaf09a4c1.png) | ![image.png](attachment:713309e9-0181-4615-8fe8-2bdd4c4d46f3.png) | ![image.png](attachment:e2ea1ec2-42ac-4a60-9b28-72baf202e441.png) | ![image.png](attachment:9b684f52-c6c1-490c-9c84-5e2eb230b975.png) | ![image.png](attachment:8c2c1d9e-701a-49ce-a75e-f5b74d54f4ae.png) |
#
#
# ### Resultados
#
# | Test   | Distancia Euclideana | Distancia Hausdorff | Distancia Frechet | Distancia DTW    | Distancia LCSS | Distancia ERP     | Distancia ERS |
# |--------|-----------------------|---------------------|-------------------|------------------|----------------|-------------------|---------------|
# | 1.1    | -                     | 0.0076             | 0.0713           | 689.6217         | 0.2469         | 21706.8486        | 180.0         |
# | 1.2    | 0.5245                | 0.0078             | 0.0713           | 151.3956         | 1.0            | 5.3098            | 60.0          |
# | 2.1    | -                     | 0.0498             | 0.0662           | 910.3010         | 0.4594         | 18155.2148        | 283.0         |
# | 2.2    | 0.4316                | 0.0499             | 0.0687           | 302.3825         | 1.0            | 5.6719            | 130.0         |
# | 3.1    | -                     | 0.0132             | 0.0132           | 1.6066           | 0.5556         | 948.7764          | 18.0          |
# | 3.2    | 0.0656                | 0.0276             | 0.0276           | 0.9778           | 1.0            | 0.2666            | 10.0          |
# | 4.1    | 0.1403                | 0.0497             | 0.0497           | 2.1205           | 1.0            | 0.5673            | 9.0           |
# | 5.1    | -                     | 0.1099             | 0.1099           | 11119.2569       | 0.4430         | 34770.5318        | 526.0         |
# | 5.2    | 0.5548                | 0.0546             | 0.0609           | 958.8139         | 1.0            | 10.0385           | 233.0         |
# | 6.1    | -                     | 0.0661             | 0.0661           | 196.6838         | 0.8            | 2138.8718         | 90.0          |
# | 6.2    | 0.5209                | 0.0661             | 0.0661           | 157.1588         | 1.0            | 5.3762            | 72.0          |

# %% [markdown]
# ## Otras pruebas

# %%
t3 = [(trajectory[1], trajectory[0]) for trajectory in g_similar_u['features'][0]['geometry']['coordinates']]
t4 = [(trajectory[1], trajectory[0] + 10) for trajectory in g_similar_u['features'][1]['geometry']['coordinates']]

utils.calculate_all(t3, t4)
# Out:
# Distancia Euclideana: 29.935035923791528
# Distancia Hausdorff: 9.980074160579044
# Distancia Frechet: 9.980074160579044
# Distancia DTW: 448.9902786247461
# Distancia LCSS: 0.5
# Distancia ERP: 90.17596258189218
# /home/edev/devel/similarity-measures/venv/lib/python3.12/site-packages/stmeasures/calculate/hausdorff.py:53: UserWarning: Args not validating
#   warnings.warn('Args not validating')
# /home/edev/devel/similarity-measures/venv/lib/python3.12/site-packages/stmeasures/calculate/frechet.py:53: UserWarning: Args not validating
#   warnings.warn('Args not validating')
# /home/edev/devel/similarity-measures/venv/lib/python3.12/site-packages/stmeasures/calculate/dtw.py:56: UserWarning: Args not validating
#   warnings.warn('Args not validating')

# %% [markdown]
# ![image.png](attachment:192caab4-a21a-41e2-975a-c2e05e104e64.png)

# %%
t3 = [(coords[1], coords[0]) for coords in g_similar_u['features'][0]['geometry']['coordinates']]
t4 = [(coords[1] - 2, coords[0] + 2) for coords in g_similar_u['features'][1]['geometry']['coordinates']]

utils.calculate_all(t3, t4)
# Out:
# Distancia Euclideana: 8.5278089856542
# Distancia Hausdorff: 2.8452876091252057
# Distancia Frechet: 2.8452876091252057
# Distancia DTW: 127.8939210201907
# Distancia ERP: 36.17596258189218
# /home/edev/devel/similarity-measures/venv/lib/python3.12/site-packages/stmeasures/calculate/hausdorff.py:53: UserWarning: Args not validating
#   warnings.warn('Args not validating')
# /home/edev/devel/similarity-measures/venv/lib/python3.12/site-packages/stmeasures/calculate/frechet.py:53: UserWarning: Args not validating
#   warnings.warn('Args not validating')
# /home/edev/devel/similarity-measures/venv/lib/python3.12/site-packages/stmeasures/calculate/dtw.py:56: UserWarning: Args not validating
#   warnings.warn('Args not validating')

# %% [markdown]
# ![image.png](attachment:e1cec7cc-40b9-4015-aac2-d37e227009a1.png)
