# %% [markdown]
# # Pruebas de rendimiento

# %%
import shapely
import stmeasures
import utils

# %%
utils.plot_timecomplexity_shapely_vs_stmeasures(shapely.distance, stmeasures.distance, 500)

# %%
utils.plot_timecomplexity_shapely_vs_stmeasures(shapely.hausdorff_distance, stmeasures.distance, 500, stmeasures.Algorithms.HAUSDORFF)
# Out:
# /home/edev/devel/similarity-measures/venv/lib/python3.12/site-packages/stmeasures/calculate/hausdorff.py:53: UserWarning: Args not validating
#   warnings.warn('Args not validating')

# %%
utils.plot_timecomplexity_shapely_vs_stmeasures(shapely.frechet_distance, stmeasures.distance, 500, stmeasures.Algorithms.FRECHET)
# Out:
# /home/edev/devel/similarity-measures/venv/lib/python3.12/site-packages/stmeasures/calculate/frechet.py:53: UserWarning: Args not validating
#   warnings.warn('Args not validating')
